# %%
# !pip install pyqrcode
# !pip install pypng
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 395.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyqrcode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36223 sha256=7b9ad0eb181ee568df51333a37ae8d0dc89181b593e46f0385853bfc35d257d1
#   Stored in directory: /root/.cache/pip/wheels/34/2d/20/082874e49a32cdcc87ebaf99dd0099fb7774ef30f010dfb6f2
# Successfully built pyqrcode
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 856.5 kB/s eta 0:00:00
# ...

# %%
import pyqrcode
import png

# %%
qr = pyqrcode.create("https://www.instagram.com/salihaksak_/")

# %%
qr.svg("insta.svg", scale = 10 )

# %%
qr.svg("insta.eps", scale = 10 )

# %%
qr.svg("insta.png", scale = 10 )

# %%
qr2 = pyqrcode.create("https://www.linkedin.com/in/salih-aksakall%C4%B1-2846b624a/")

# %%
qr2.svg("Linkedln.svg", scale = 10 )

# %%
qr2.svg("Linkedln.png", scale = 10 )

# %%
qr2.svg("Linkedln.eps", scale = 10 )

# %%
qr.png("instacolor.png",scale = 10 , background=(205,133,63,255))

# %%
qr.png("instacolor2.png",scale = 10 , module_color=(82,139,139,255))

# %%
qr2.png("Linkedln1.png",scale = 10 , background=(238,232,170,255))

# %%
qr2.png("Linkedln3.png",scale = 10 , module_color=(82,139,139,255))

# %%
qr2.png("Linkedln2.png",scale = 10 , background=(238,232,170,255),module_color=(82,139,139,255))
